# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv',\
    nrows = 6606)
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2018  2190.240321              NaN
# 1     Afghanistan  2017  2202.570851              NaN
# 2     Afghanistan  2016  2200.764487              NaN
# 3     Afghanistan  2015  2212.750899              NaN
# 4     Afghanistan  2014  2249.253738              NaN
# 5     Afghanistan  2013  2264.317575              NaN

# %%
internet_df = pd.read_csv('../data/internet_use.csv',\
    nrows = 4495)
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
debt_df = pd.read_csv('../data/external_debt_pct.csv')
debt_df.head(6)
# Out:
#   Country or Area  Year      Value  Value Footnotes
# 0     Afghanistan  2018  13.614964              NaN
# 1     Afghanistan  2017  13.463680              NaN
# 2     Afghanistan  2016  13.284334              NaN
# 3     Afghanistan  2015  12.928298              NaN
# 4     Afghanistan  2014  12.351341              NaN
# 5     Afghanistan  2013  12.542040              NaN

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
type(internet_df)
# Out:
# pandas.core.frame.DataFrame

# %%
debt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5121 entries, 0 to 5120
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  5121 non-null   object
#  1   Year             5121 non-null   int64
#  2   Value            5121 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 160.2+ KB

# %%
gdp_df.shape
# Out:
# (6606, 4)

# %% [markdown]
# ### gdp_df shape 6606 rows and 4 columns

# %%
internet_df.shape
# Out:
# (4495, 4)

# %% [markdown]
# ### internet_df shape 4495 rows and 4 columns

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6596        Zimbabwe  1999  3600.849291              NaN
# 6597        Zimbabwe  1998  3653.920016              NaN
# 6598        Zimbabwe  1997  3580.048793              NaN
# 6599        Zimbabwe  1996  3520.430146              NaN
# 6600        Zimbabwe  1995  3226.413930              NaN
# 6601        Zimbabwe  1994  3263.934978              NaN
# 6602        Zimbabwe  1993  3033.504852              NaN
# 6603        Zimbabwe  1992  3054.889178              NaN
# 6604        Zimbabwe  1991  3426.598094              NaN
# 6605        Zimbabwe  1990  3324.348171              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %%
debt_df.tail(10)
# Out:
#      Country or Area  Year      Value  Value Footnotes
# 5111        Zimbabwe  1979  10.967762              NaN
# 5112        Zimbabwe  1978  10.392577              NaN
# 5113        Zimbabwe  1977   4.650127              NaN
# 5114        Zimbabwe  1976   3.389576              NaN
# 5115        Zimbabwe  1975   4.337084              NaN
# 5116        Zimbabwe  1974   5.533279              NaN
# 5117        Zimbabwe  1973   6.649096              NaN
# 5118        Zimbabwe  1972   8.280484              NaN
# 5119        Zimbabwe  1971  11.101511              NaN
# 5120        Zimbabwe  1970  12.471113              NaN

# %%
gdp_df = gdp_df.drop(columns = 'Value Footnotes')

# %%
gdp_df.head(2)
# Out:
#   Country or Area  Year        Value
# 0     Afghanistan  2018  2190.240321
# 1     Afghanistan  2017  2202.570851

# %%
gdp_df.tail(2)
# Out:
#      Country or Area  Year        Value
# 6604        Zimbabwe  1991  3426.598094
# 6605        Zimbabwe  1990  3324.348171

# %%
internet_df = internet_df.drop(columns = 'Value Footnotes')

# %%
internet_df.head(2)
# Out:
#   Country or Area  Year  Value
# 0     Afghanistan  2014   6.39
# 1     Afghanistan  2013   5.90

# %%
internet_df.tail(2)
# Out:
#      Country or Area  Year     Value
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000

# %%
debt_df = debt_df.drop(columns = 'Value Footnotes')
debt_df.tail()
# Out:
#      Country or Area  Year      Value
# 5116        Zimbabwe  1974   5.533279
# 5117        Zimbabwe  1973   6.649096
# 5118        Zimbabwe  1972   8.280484
# 5119        Zimbabwe  1971  11.101511
# 5120        Zimbabwe  1970  12.471113

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value'], dtype='object')

# %%
gdp_df.columns = ['Country', 'Year', 'GDP_Per_Capita']
gdp_df.head(2)
# Out:
#        Country  Year  GDP_Per_Capita
# 0  Afghanistan  2018     2190.240321
# 1  Afghanistan  2017     2202.570851

# %%
internet_df.columns = ['Country', 'Year', 'Internet_Users_Pct']
internet_df.head(2)
# Out:
#        Country  Year  Internet_Users_Pct
# 0  Afghanistan  2014                6.39
# 1  Afghanistan  2013                5.90

# %%
debt_df.columns = ['Country', 'Year', 'External_Debt_Pct']
debt_df.head(2)
# Out:
#        Country  Year  External_Debt_Pct
# 0  Afghanistan  2018          13.614964
# 1  Afghanistan  2017          13.463680

# %%
#gdp_df.info()
#internet_df.info()
debt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5121 entries, 0 to 5120
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            5121 non-null   object
#  1   Year               5121 non-null   int64
#  2   External_Debt_Pct  5121 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 120.1+ KB

# %%
gdp_and_internet_use = gdp_df.merge(internet_df,\
    on = ['Country', 'Year'], how = 'outer')

# %%
gdp_internet_debt = gdp_and_internet_use.merge(debt_df,\
    on = ['Country', 'Year'], how = 'outer')

# %%
gdp_and_internet_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7664 entries, 0 to 7663
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             7664 non-null   object
#  1   Year                7664 non-null   int64
#  2   GDP_Per_Capita      6606 non-null   float64
#  3   Internet_Users_Pct  4495 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 299.4+ KB

# %%
gdp_and_internet_use.head(2)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2018     2190.240321                 NaN
# 1  Afghanistan  2017     2202.570851                 NaN

# %%
gdp_and_internet_use.shape
# Out:
# (7664, 4)

# %%
internet_df.shape
# Out:
# (4495, 3)

# %%
gdp_df.shape
# Out:
# (6606, 3)

# %%
gdp_and_internet_use.query('Country == "Afghanistan"')
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2018     2190.240321                 NaN
# 1     Afghanistan  2017     2202.570851                 NaN
# 2     Afghanistan  2016     2200.764487                 NaN
# 3     Afghanistan  2015     2212.750899                 NaN
# 4     Afghanistan  2014     2249.253738            6.390000
# 5     Afghanistan  2013     2264.317575            5.900000
# 6     Afghanistan  2012     2220.481526            5.454545
# 7     Afghanistan  2011     2037.608607            5.000000
# 8     Afghanistan  2010     2093.743565            4.000000
# 9     Afghanistan  2009     1881.777626            3.550000
# 10    Afghanistan  2008     1587.792070            1.840000
# 11    Afghanistan  2007     1562.876516            1.900000
# 12    Afghanistan  2006     1407.708041            2.107124
# 13    Afghanistan  2005     1376.686376            1.224148
# 14    Afghanistan  2004     1284.127338            0.105809
# ...

# %%
gdp_and_internet_use = gdp_and_internet_use.\
    sort_values(['Country', 'Year'])
gdp_and_internet_use.head(20)
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6607  Afghanistan  1990             NaN            0.000000
# 6606  Afghanistan  2001             NaN            0.004723
# 16    Afghanistan  2002     1272.900914            0.004561
# 15    Afghanistan  2003     1322.141328            0.087891
# 14    Afghanistan  2004     1284.127338            0.105809
# 13    Afghanistan  2005     1376.686376            1.224148
# 12    Afghanistan  2006     1407.708041            2.107124
# 11    Afghanistan  2007     1562.876516            1.900000
# 10    Afghanistan  2008     1587.792070            1.840000
# 9     Afghanistan  2009     1881.777626            3.550000
# 8     Afghanistan  2010     2093.743565            4.000000
# 7     Afghanistan  2011     2037.608607            5.000000
# 6     Afghanistan  2012     2220.481526            5.454545
# 5     Afghanistan  2013     2264.317575            5.900000
# 4     Afghanistan  2014     2249.253738            6.390000
# ...

# %%
gdp_internet_debt = gdp_internet_debt.\
    sort_values(['Country', 'Year'])
gdp_internet_debt.head(20)
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct  External_Debt_Pct
# 6607  Afghanistan  1990             NaN            0.000000                NaN
# 6606  Afghanistan  2001             NaN            0.004723                NaN
# 16    Afghanistan  2002     1272.900914            0.004561                NaN
# 15    Afghanistan  2003     1322.141328            0.087891                NaN
# 14    Afghanistan  2004     1284.127338            0.105809                NaN
# 13    Afghanistan  2005     1376.686376            1.224148                NaN
# 12    Afghanistan  2006     1407.708041            2.107124                NaN
# 11    Afghanistan  2007     1562.876516            1.900000                NaN
# 10    Afghanistan  2008     1587.792070            1.840000                NaN
# 9     Afghanistan  2009     1881.777626            3.550000          19.995894
# 8     Afghanistan  2010     2093.743565            4.000000          15.334722
# ...

# %%
gdp_and_internet_use = gdp_and_internet_use.\
    reset_index(drop=True)
gdp_and_internet_use.head(20)
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0   Afghanistan  1990             NaN            0.000000
# 1   Afghanistan  2001             NaN            0.004723
# 2   Afghanistan  2002     1272.900914            0.004561
# 3   Afghanistan  2003     1322.141328            0.087891
# 4   Afghanistan  2004     1284.127338            0.105809
# 5   Afghanistan  2005     1376.686376            1.224148
# 6   Afghanistan  2006     1407.708041            2.107124
# 7   Afghanistan  2007     1562.876516            1.900000
# 8   Afghanistan  2008     1587.792070            1.840000
# 9   Afghanistan  2009     1881.777626            3.550000
# 10  Afghanistan  2010     2093.743565            4.000000
# 11  Afghanistan  2011     2037.608607            5.000000
# 12  Afghanistan  2012     2220.481526            5.454545
# 13  Afghanistan  2013     2264.317575            5.900000
# 14  Afghanistan  2014     2249.253738            6.390000
# ...

# %%
gdp_internet_debt = gdp_internet_debt.\
    reset_index(drop=True)
gdp_internet_debt.head(20)
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct  External_Debt_Pct
# 0   Afghanistan  1990             NaN            0.000000                NaN
# 1   Afghanistan  2001             NaN            0.004723                NaN
# 2   Afghanistan  2002     1272.900914            0.004561                NaN
# 3   Afghanistan  2003     1322.141328            0.087891                NaN
# 4   Afghanistan  2004     1284.127338            0.105809                NaN
# 5   Afghanistan  2005     1376.686376            1.224148                NaN
# 6   Afghanistan  2006     1407.708041            2.107124                NaN
# 7   Afghanistan  2007     1562.876516            1.900000                NaN
# 8   Afghanistan  2008     1587.792070            1.840000                NaN
# 9   Afghanistan  2009     1881.777626            3.550000          19.995894
# 10  Afghanistan  2010     2093.743565            4.000000          15.334722
# ...

# %%
gdp_and_internet_use.tail()
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7659  Zimbabwe  2014     2955.240287               19.89
# 7660  Zimbabwe  2015     2958.209004                 NaN
# 7661  Zimbabwe  2016     2934.733650                 NaN
# 7662  Zimbabwe  2017     3028.245976                 NaN
# 7663  Zimbabwe  2018     3130.029501                 NaN

# %%
gdp_and_internet_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7664 entries, 0 to 7663
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             7664 non-null   object
#  1   Year                7664 non-null   int64
#  2   GDP_Per_Capita      6606 non-null   float64
#  3   Internet_Users_Pct  4495 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 239.6+ KB

# %%
subset_gdp_internet = gdp_and_internet_use.query('Year == 2004 or Year == 2009 or Year == 2014')
subset_gdp_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 830 entries, 4 to 7659
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             830 non-null    object
#  1   Year                830 non-null    int64
#  2   GDP_Per_Capita      705 non-null    float64
#  3   Internet_Users_Pct  604 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 32.4+ KB

# %%
subset_gdp_internet_debt = gdp_internet_debt.query('Year == 2004 or Year == 2009 or Year == 2014')
subset_gdp_internet_debt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 831 entries, 4 to 9196
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             831 non-null    object
#  1   Year                831 non-null    int64
#  2   GDP_Per_Capita      705 non-null    float64
#  3   Internet_Users_Pct  604 non-null    float64
#  4   External_Debt_Pct   379 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 39.0+ KB

# %%
gdp_internet_2004 = subset_gdp_internet.query('Year == 2004')
gdp_internet_2009 = subset_gdp_internet.query('Year == 2009')
gdp_internet_2014 = subset_gdp_internet.query('Year == 2014')

# %%
gdp_internet_debt_2004 = subset_gdp_internet_debt.query('Year == 2004')
gdp_internet_debt_2009 = subset_gdp_internet_debt.query('Year == 2009')
gdp_internet_debt_2014 = subset_gdp_internet_debt.query('Year == 2014')

# %%
gdp_internet_2004 = gdp_internet_2004.reset_index(drop = True)
gdp_internet_2009 = gdp_internet_2009.reset_index(drop = True)
gdp_internet_2014 = gdp_internet_2014.reset_index(drop = True)

# %%
gdp_internet_debt_2004 = gdp_internet_debt_2004.reset_index(drop = True)
gdp_internet_debt_2009 = gdp_internet_debt_2009.reset_index(drop = True)
gdp_internet_debt_2014 = gdp_internet_debt_2014.reset_index(drop = True)

# %%
print(gdp_internet_2014[gdp_internet_2014['Internet_Users_Pct']\
    ==gdp_internet_2014['Internet_Users_Pct'].max()])
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 111  Iceland  2014    49911.069825               98.16

# %%
print(gdp_internet_debt_2014[gdp_internet_debt_2014['External_Debt_Pct']\
    ==gdp_internet_debt_2014['External_Debt_Pct'].max()])
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct  External_Debt_Pct
# 170  Mongolia  2014      10980.3352                27.0         188.655005

# %% [markdown]
# ## Highest Inernet Users
# ### 111  Iceland  2014   GDP = 49911.069825, Internet_Pct=98.16
# ### 240  Sweden  2004   GDP=45029.814344, Internet_Pct=83.89
# ### 113  Iceland  2009    GDP=48428.312438, Internet_Pct=93.0

# %%
print(gdp_internet_2014[gdp_internet_2014['Internet_Users_Pct']\
    ==gdp_internet_2014['Internet_Users_Pct'].min()])
# Out:
#                         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 57  Dem. People's Rep. of Korea  2014             NaN                 0.0

# %% [markdown]
# ## Lowest Internet Users
# ### 57  Dem. People's Rep. of Korea  2014  GDP=NaN, Internet_Pct=0.0
# ### 56  Dem. People's Rep. of Korea  2004  GDP=NaN, Internet_Pct=0.0
# ### 57  Dem. People's Rep. of Korea  2009  GDP=NaN, Internet_Pct=0.0

# %%
print(gdp_internet_2004[gdp_internet_2004['Internet_Users_Pct']\
    ==gdp_internet_2004['Internet_Users_Pct'].max()])
# Out:
#     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 240  Sweden  2004    45029.814344               83.89

# %%
print(gdp_internet_2004[gdp_internet_2004['Internet_Users_Pct']\
    ==gdp_internet_2004['Internet_Users_Pct'].min()])
# Out:
#                         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 56  Dem. People's Rep. of Korea  2004             NaN                 0.0

# %%
print(gdp_internet_2009[gdp_internet_2009['Internet_Users_Pct']\
    ==gdp_internet_2009['Internet_Users_Pct'].max()])
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 113  Iceland  2009    48428.312438                93.0

# %%
print(gdp_internet_2009[gdp_internet_2009['Internet_Users_Pct']\
    ==gdp_internet_2009['Internet_Users_Pct'].min()])
# Out:
#                         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 57  Dem. People's Rep. of Korea  2009             NaN                 0.0

# %%
print(gdp_internet_2014[gdp_internet_2014['GDP_Per_Capita']\
    ==gdp_internet_2014['GDP_Per_Capita'].max()])
# Out:
#               Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 150  Macao SAR, China  2014    156514.13385                 NaN

# %% [markdown]
# ## Highest and Lowest GDP in 2014
# ### 150  Macao SAR, China  2014 GDP=156514.13385, Internet_Pct=NaN
# ### 40  Central African Republic  2014 GDP=822.610458, Internet_Pct=NaN

# %%
print(gdp_internet_2014[gdp_internet_2014['GDP_Per_Capita']\
    ==gdp_internet_2014['GDP_Per_Capita'].min()])
# Out:
#                      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 40  Central African Republic  2014      822.610458                 NaN

# %%
plt.scatter(x = 'Internet_Users_Pct', y ='GDP_Per_Capita', color ='c', data = gdp_internet_2004)
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita')
plt.title('Internet Usage vs GDP 2004');

# %%
plt.scatter(x = 'Internet_Users_Pct', y ='GDP_Per_Capita', color ='m', data = gdp_internet_2009)
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita')
plt.title('Internet Usage vs GDP 2009');

# %%
plt.scatter(x = 'Internet_Users_Pct', y ='GDP_Per_Capita', color ='y', data = gdp_internet_2014)
plt.xlabel('Internet_Users_Pct')
plt.ylabel('GDP_Per_Capita')
plt.title('Internet Usage vs GDP 2014');

# %% [markdown]
# ## Internet Usage vs GDP
# ### Years 2004, 2009, and 2014: Increase GDP and Increase Internet Usage
# ### Overtime it appears that Internet usage is becoming more available to countries with lower GDPs

# %%
sns.distplot(gdp_internet_2014['GDP_Per_Capita'], bins=25);

# %%
sns.distplot(gdp_internet_2014['Internet_Users_Pct'], bins=25);

# %%
sns.distplot(gdp_internet_debt_2014['External_Debt_Pct'], bins=25);

# %% [markdown]
# ### GDP is unimodal whereas Internet is bimodal in 2014

# %%
internet_2014_top_5 = gdp_internet_2014.\
    sort_values(['Internet_Users_Pct'], ascending = False).head()
internet_2014_top_5
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 111  Iceland  2014    49911.069825               98.16
# 21   Bermuda  2014             NaN               96.80
# 186   Norway  2014    61308.763730               96.30
# 59   Denmark  2014    52172.606425               95.99
# 3    Andorra  2014             NaN               95.90

# %% [markdown]
# ## Top 5 Countries for Internet in 2014
# ### Iceland, Bermuda, Norway, Denmark, Andorra

# %%
top_5_internet = subset_gdp_internet.query('Country ==\
    ["Iceland", "Bermuda", "Norway", "Denmark", "Andorra"]').reset_index(drop = True)
top_5_internet.head(20)
# Out:
#     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0   Andorra  2004             NaN           26.837954
# 1   Andorra  2009             NaN           78.530000
# 2   Andorra  2014             NaN           95.900000
# 3   Bermuda  2004             NaN           60.990867
# 4   Bermuda  2009             NaN           83.250000
# 5   Bermuda  2014             NaN           96.800000
# 6   Denmark  2004    50566.988088           80.930000
# 7   Denmark  2009    50233.702688           86.840000
# 8   Denmark  2014    52172.606425           95.990000
# 9   Iceland  2004    45380.965464           83.880000
# 10  Iceland  2009    48428.312438           93.000000
# 11  Iceland  2014    49911.069825           98.160000
# 12   Norway  2004    59647.501415           77.690000
# 13   Norway  2009    60620.334503           92.080000
# 14   Norway  2014    61308.763730           96.300000

# %%
graph = sns.FacetGrid(top_5_internet, col ="Country") 
graph.map(plt.scatter, "Year", "Internet_Users_Pct")
graph.set(ylim=(0, 100))
graph.fig.subplots_adjust(top=0.8)
graph.fig.suptitle('Top 5 Internet Pct');

# %%
debt_2014_top_5 = gdp_internet_debt_2014.\
    sort_values(['External_Debt_Pct'], ascending = False).head()
debt_2014_top_5
# Out:
#         Country  Year  GDP_Per_Capita  Internet_Users_Pct  External_Debt_Pct
# 170    Mongolia  2014    10980.335200               27.00         188.655005
# 171  Montenegro  2014    17625.052336               61.00         141.308177
# 140     Lebanon  2014    16966.739879               74.70         135.370936
# 120     Jamaica  2014     9436.058110               40.50         103.961792
# 22       Bhutan  2014     9573.989060               34.37         103.896795

# %%
top_5_debt = subset_gdp_internet_debt.query('Country ==\
    ["Mongolia", "Montenegro", "Lebanon", "Jamaica", "Bhutan"]').reset_index(drop = True)
top_5_debt.head(20)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct  External_Debt_Pct
# 0       Bhutan  2004     5165.124956            3.156984          90.213665
# 1       Bhutan  2009     7393.983256            7.170000          66.462854
# 2       Bhutan  2014     9573.989060           34.370000         103.896795
# 3      Jamaica  2004     9883.128886           10.000000          68.480816
# 4      Jamaica  2009     9625.168132           24.300000          97.557644
# 5      Jamaica  2014     9436.058110           40.500000         103.961792
# 6      Lebanon  2004    14283.959712            9.000000         112.051967
# 7      Lebanon  2009    18584.383635           30.140000         131.188338
# 8      Lebanon  2014    16966.739879           74.700000         135.370936
# 9     Mongolia  2004     5551.467146                 NaN          80.444555
# 10    Mongolia  2009     7153.432100           10.000000          68.090614
# ...

# %%
graphd = sns.FacetGrid(top_5_debt, col ="Country") 
graphd.map(plt.scatter, "Year", "External_Debt_Pct")
graphd.set(ylim=(0, 200))
graphd.fig.subplots_adjust(top=0.8)
graphd.fig.suptitle('Top 5 External Debt Pct');

# %% [markdown]
# ### Andorra had the greatest internet growth between 2004 and 2014

# %%
internet_2014_btm_5 = gdp_internet_2014.\
    sort_values(['Internet_Users_Pct']).head()
internet_2014_btm_5
# Out:
#                          Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 57   Dem. People's Rep. of Korea  2014             NaN                0.00
# 72                       Eritrea  2014             NaN                0.99
# 250                  Timor-Leste  2014     3264.739189                1.14
# 31                       Burundi  2014      886.235777                1.38
# 224                      Somalia  2014             NaN                1.63

# %% [markdown]
# ## Bottom 5 Countries for Internet in 2014
# ### Dem. People's Rep. of Korea, Eritrea, Timor-Leste, Burundi, Somalia

# %%
btm_5_internet = subset_gdp_internet.query('Country ==\
    ["Dem. People\'s Rep. of Korea", "Eritrea", "Timor-Leste", "Burundi", "Somalia"]')\
    .reset_index(drop = True)
btm_5_internet.head(20)
# Out:
#                         Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0                       Burundi  2004      817.460585            0.349060
# 1                       Burundi  2009      831.564131            0.900000
# 2                       Burundi  2014      886.235777            1.380000
# 3   Dem. People's Rep. of Korea  2004             NaN            0.000000
# 4   Dem. People's Rep. of Korea  2009             NaN            0.000000
# 5   Dem. People's Rep. of Korea  2014             NaN            0.000000
# 6                       Eritrea  2009             NaN            0.540000
# 7                       Eritrea  2014             NaN            0.990000
# 8                       Somalia  2004             NaN            1.053455
# 9                       Somalia  2009             NaN            1.160611
# 10                      Somalia  2014             NaN            1.630000
# 11                  Timor-Leste  2004     2258.707771                 NaN
# ...

# %%
graph2 = sns.FacetGrid(btm_5_internet, col ="Country") 
graph2.map(plt.scatter, "Year", "Internet_Users_Pct")
graph2.set(ylim=(0, 2))
graph2.fig.subplots_adjust(top=0.8)
graph2.fig.suptitle('Bottom 5 Internet Pct');

# %%
debt_2014_btm_5 = gdp_internet_debt_2014.\
    sort_values(['External_Debt_Pct']).head()
debt_2014_btm_5
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct  External_Debt_Pct
# 256  Turkmenistan  2014    12421.360682               12.20           1.034900
# 114          Iran  2014    13038.559438                 NaN           1.340600
# 2         Algeria  2014    11329.428688               18.09           2.641514
# 250   Timor-Leste  2014     3264.739189                1.14           3.125246
# 183       Nigeria  2014     5516.386504               42.68           5.210915

# %%
btm_5_debt = subset_gdp_internet_debt.query('Country ==\
    ["Turkmenistan", "Iran", "Algeria", "Timor-Leste", "Nigeria"]')\
    .reset_index(drop = True)
btm_5_debt.head(20)
# Out:
#          Country  Year  GDP_Per_Capita  Internet_Users_Pct  External_Debt_Pct
# 0        Algeria  2004     9898.310490            4.634475          27.399592
# 1        Algeria  2009    10610.711405           11.230000           5.455776
# 2        Algeria  2014    11329.428688           18.090000           2.641514
# 3           Iran  2004    11764.098018                 NaN          11.041892
# 4           Iran  2009    13199.019665                 NaN           4.470603
# 5           Iran  2014    13038.559438                 NaN           1.340600
# 6        Nigeria  2004     3854.008007            1.286138          35.217387
# 7        Nigeria  2009     4690.379631           20.000000           6.954361
# 8        Nigeria  2014     5516.386504           42.680000           5.210915
# 9    Timor-Leste  2004     2258.707771                 NaN                NaN
# 10   Timor-Leste  2009     2724.834868            0.185252                NaN
# ...

# %%
graphd2 = sns.FacetGrid(btm_5_debt, col ="Country") 
graphd2.map(plt.scatter, "Year", "External_Debt_Pct")
graphd2.set(ylim=(0, 40))
graphd2.fig.subplots_adjust(top=0.8)
graphd2.fig.suptitle('Bottom 5 External Debt Pct');

# %% [markdown]
# ### Dem. People's Rep. of Korea consistently had the least internet use

# %%
GDP_2014_top_5 = gdp_internet_2014.\
    sort_values(['GDP_Per_Capita'], ascending = False).head()
GDP_2014_top_5
# Out:
#               Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 150  Macao SAR, China  2014   156514.133850                 NaN
# 149        Luxembourg  2014   108911.348894               94.67
# 204             Qatar  2014    97938.305225               91.49
# 218         Singapore  2014    87808.663157               82.00
# 38     Cayman Islands  2014    66195.475587               74.10

# %%
top_5_GDP = subset_gdp_internet.query('Country ==\
    ["Macao SAR, China", "Luxembourg", "Qatar", "Singapore", "Cayman Islands"]').reset_index(drop = True)
top_5_GDP.head(20)
# Out:
#              Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Cayman Islands  2009    70287.622992           64.500000
# 1     Cayman Islands  2014    66195.475587           74.100000
# 2         Luxembourg  2004   102850.273309           65.880000
# 3         Luxembourg  2009   105077.951508           87.310000
# 4         Luxembourg  2014   108911.348894           94.670000
# 5   Macao SAR, China  2004    72944.409424                 NaN
# 6   Macao SAR, China  2009    95939.340822                 NaN
# 7   Macao SAR, China  2014   156514.133850                 NaN
# 8              Qatar  2004    98423.340291           20.701648
# 9              Qatar  2009    94440.370835           53.100000
# 10             Qatar  2014    97938.305225           91.490000
# 11         Singapore  2004    63901.716368           62.000000
# 12         Singapore  2009    69466.581746           69.000000
# 13         Singapore  2014    87808.663157           82.000000

# %%
graph3 = sns.FacetGrid(top_5_GDP, col ="Country") 
graph3.map(plt.scatter, "Year", "GDP_Per_Capita")
graph3.set(ylim=(0, 160000))
graph3.fig.subplots_adjust(top=0.8)
graph3.fig.suptitle('Top 5 GDP');

# %%
GDP_2014_btm_5 = gdp_internet_2014.\
    sort_values(['GDP_Per_Capita']).head()
GDP_2014_btm_5
# Out:
#                       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 40   Central African Republic  2014      822.610458                 NaN
# 31                    Burundi  2014      886.235777                1.38
# 153                    Malawi  2014     1027.208496                5.83
# 58            Dem. Rep. Congo  2014     1029.790785                 NaN
# 182                     Niger  2014     1126.153622                1.95

# %%
btm_5_GDP = subset_gdp_internet.query('Country ==\
    ["Central African Republic", "Burundi", "Malawi", "Dem. Rep. Congo", "Niger"]').reset_index(drop = True)
btm_5_GDP.head(20)
# Out:
#                      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0                    Burundi  2004      817.460585            0.349060
# 1                    Burundi  2009      831.564131            0.900000
# 2                    Burundi  2014      886.235777            1.380000
# 3   Central African Republic  2004     1037.846766                 NaN
# 4   Central African Republic  2009     1161.189475                 NaN
# 5   Central African Republic  2014      822.610458                 NaN
# 6            Dem. Rep. Congo  2004      757.685942                 NaN
# 7            Dem. Rep. Congo  2009      835.611696                 NaN
# 8            Dem. Rep. Congo  2014     1029.790785                 NaN
# 9                     Malawi  2004      775.346132            0.347505
# 10                    Malawi  2009      932.867635            1.070000
# 11                    Malawi  2014     1027.208496            5.830000
# ...

# %%
graph4 = sns.FacetGrid(btm_5_GDP, col ="Country") 
graph4.map(plt.scatter, "Year", "GDP_Per_Capita")
graph4.set(ylim=(0, 1200))
graph4.fig.subplots_adjust(top=0.8)
graph4.fig.suptitle('Bottom 5 GDP');

# %% [markdown]
# ## Interesting info from plots?
# ### Top 5 Internet: Andorra had highest growth of internet use in 10 years.
# ### Btm 5 Internet: Dem. People's Rep. of Korea has no internet use. The govt controls internet access which is mostly non-existent. src. US Dept of State
# ### Top 5 GDP: Macao SAR, China doubled GDP in 10 years. "the tourism and gaming industry, dominates Macau's economy contributing over 90% of GDP output, also considered a tax haven" src. investopedia
# ### Btm 5 GDP: Central African Republic dropped in 2014 from previous growth. CAR has an unstable govt and saw an violent overthrow by Séléka rebels in 2012, 2013, etc. src university of central arkansas
#
# ## Bonus: Comparing % External Debt to GNI
# ### Top 5 external debt % countries are increasing that % from 2004 to 2014: Mongolia, Montenegro, Lebanon, Jamaica, Bhutan
# ### Bottom 5 external debt % countries are decreasing that % from 2004 to 2014: Turkmenistan, Iran, Algeria, Timor-Leste, Nigeria
